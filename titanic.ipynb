# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('full.csv', index_col = 0)

# %%
print(data)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# ...               ...     ...
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 1305                                        Spector, Mr. Woolf    male   NaN
# 1306                              Oliva y Ocana, Dona. Fermina  female  39.0
# 1307                              Saether, Mr. Simon Sivertsen    male  38.5
# 1308                                       Ware, Mr. Frederick    male   NaN
# 1309                                  Peter, Master. Michael J    male   NaN
#
#              SibSp  Parch              Ticket      Fare Cabin Embarked  \
# PassengerId
# 1                1      0           A/5 21171    7.2500   NaN        S
# 2                1      0            PC 17599   71.2833   C85        C
# 3                0      0    STON/O2. 3101282    7.9250   NaN        S
# 4                1      0              113803   53.1000  C123        S
# 5                0      0              373450    8.0500   NaN        S
# ...            ...    ...                 ...       ...   ...      ...
# 1305             0      0           A.5. 3236    8.0500   NaN        S
# 1306             0      0            PC 17758  108.9000  C105        C
# 1307             0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308             0      0              359309    8.0500   NaN        S
# 1309             1      1                2668   22.3583   NaN        C
#
#              WikiId                                   Name_wiki  Age_wiki  \
# PassengerId
# 1             691.0                     Braund, Mr. Owen Harris      22.0
# 2              90.0  Cumings, Mrs. Florence Briggs (née Thayer)      35.0
# 3             865.0                       Heikkinen, Miss Laina      26.0
# 4             127.0          Futrelle, Mrs. Lily May (née Peel)      35.0
# 5             627.0                    Allen, Mr. William Henry      35.0
# ...             ...                                         ...       ...
# 1305         1227.0                          Spector, Mr. Woolf      23.0
# 1306          229.0        and maid, Doña Fermina Oliva y Ocana      39.0
# 1307         1169.0                 Sæther, Mr. Simon Sivertsen      43.0
# 1308         1289.0                 Ware, Mr. Frederick William      34.0
# 1309          702.0             Butrus-Youssef, Master Makhkhul       4.0
#
#                                        Hometown      Boarded  \
# PassengerId
# 1                    Bridgerule, Devon, England  Southampton
# 2                        New York, New York, US    Cherbourg
# 3                            Jyväskylä, Finland  Southampton
# 4                   Scituate, Massachusetts, US  Southampton
# 5            Birmingham, West Midlands, England  Southampton
# ...                                         ...          ...
# 1305                            London, England  Southampton
# 1306                              Madrid, Spain    Cherbourg
# 1307               Skaun, Sør-Trøndelag, Norway  Southampton
# 1308                 Greenwich, London, England  Southampton
# 1309                          Sar'al[81], Syria    Cherbourg
#
#                                          Destination Lifeboat  Body  Class
# PassengerId
# 1            Qu'Appelle Valley, Saskatchewan, Canada      NaN   NaN    3.0
# 2                             New York, New York, US        4   NaN    1.0
# 3                                      New York City      14?   NaN    3.0
# 4                        Scituate, Massachusetts, US        D   NaN    1.0
# 5                                      New York City      NaN   NaN    3.0
# ...                                              ...      ...   ...    ...
# 1305                                   New York City      NaN   NaN    3.0
# 1306                          New York, New York, US        8   NaN    1.0
# 1307                                              US      NaN  32MB    3.0
# 1308                                   New York City      NaN   NaN    3.0
# 1309                           Detroit, Michigan, US        D   NaN    3.0
#
# [1309 rows x 20 columns]

# %%
data.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# 6                 0.0       3
# 7                 0.0       1
# 8                 0.0       3
# 9                 1.0       3
# 10                1.0       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  WikiId  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S   691.0
# 2                1      0          PC 17599  71.2833   C85        C    90.0
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S   865.0
# 4                1      0            113803  53.1000  C123        S   127.0
# 5                0      0            373450   8.0500   NaN        S   627.0
# 6                0      0            330877   8.4583   NaN        Q   785.0
# 7                0      0             17463  51.8625   E46        S   200.0
# 8                3      1            349909  21.0750   NaN        S  1108.0
# 9                0      2            347742  11.1333   NaN        S   902.0
# 10               1      0            237736  30.0708   NaN        C   520.0
#
#                                                  Name_wiki  Age_wiki  \
# PassengerId
# 1                                  Braund, Mr. Owen Harris      22.0
# 2               Cumings, Mrs. Florence Briggs (née Thayer)      35.0
# 3                                    Heikkinen, Miss Laina      26.0
# 4                       Futrelle, Mrs. Lily May (née Peel)      35.0
# 5                                 Allen, Mr. William Henry      35.0
# 6            Doherty, Mr. William John (aka "James Moran")      22.0
# 7                                 McCarthy, Mr. Timothy J.      54.0
# 8                            Pålsson, Master Gösta Leonard       2.0
# 9            Johnson, Mrs. Elisabeth Vilhelmina (née Berg)      26.0
# 10               Nassr Allah, Mrs. Adal (née Akim)[62][77]      14.0
#
#                                        Hometown      Boarded  \
# PassengerId
# 1                    Bridgerule, Devon, England  Southampton
# 2                        New York, New York, US    Cherbourg
# 3                            Jyväskylä, Finland  Southampton
# 4                   Scituate, Massachusetts, US  Southampton
# 5            Birmingham, West Midlands, England  Southampton
# 6                                 Cork, Ireland   Queenstown
# 7                 Dorchester, Massachusetts, US  Southampton
# 8                           Bjuv, Skåne, Sweden  Southampton
# 9                     St. Charles, Illinois, US  Southampton
# 10               Zahlé, Lebanon, Ottoman Empire    Cherbourg
#
#                                          Destination Lifeboat   Body  Class
# PassengerId
# 1            Qu'Appelle Valley, Saskatchewan, Canada      NaN    NaN    3.0
# 2                             New York, New York, US        4    NaN    1.0
# 3                                      New York City      14?    NaN    3.0
# 4                        Scituate, Massachusetts, US        D    NaN    1.0
# 5                                      New York City      NaN    NaN    3.0
# 6                                      New York City      NaN    NaN    3.0
# 7                      Dorchester, Massachusetts, US      NaN  175MB    1.0
# 8                              Chicago, Illinois, US      NaN    NaN    3.0
# 9                          St. Charles, Illinois, US       15    NaN    3.0
# 10                               Cleveland, Ohio, US        ?    NaN    2.0

# %%
data.tail(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1300              NaN       3
# 1301              NaN       3
# 1302              NaN       3
# 1303              NaN       1
# 1304              NaN       3
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                         Name     Sex   Age  \
# PassengerId
# 1300                         Riordan, Miss. Johanna Hannah""  female   NaN
# 1301                               Peacock, Miss. Treasteall  female   3.0
# 1302                                  Naughton, Miss. Hannah  female   NaN
# 1303         Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0
# 1304                          Henriksson, Miss. Jenny Lovisa  female  28.0
# 1305                                      Spector, Mr. Woolf    male   NaN
# 1306                            Oliva y Ocana, Dona. Fermina  female  39.0
# 1307                            Saether, Mr. Simon Sivertsen    male  38.5
# 1308                                     Ware, Mr. Frederick    male   NaN
# 1309                                Peter, Master. Michael J    male   NaN
#
#              SibSp  Parch              Ticket      Fare Cabin Embarked  \
# PassengerId
# 1300             0      0              334915    7.7208   NaN        Q
# 1301             1      1  SOTON/O.Q. 3101315   13.7750   NaN        S
# 1302             0      0              365237    7.7500   NaN        Q
# 1303             1      0               19928   90.0000   C78        Q
# 1304             0      0              347086    7.7750   NaN        S
# 1305             0      0           A.5. 3236    8.0500   NaN        S
# 1306             0      0            PC 17758  108.9000  C105        C
# 1307             0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308             0      0              359309    8.0500   NaN        S
# 1309             1      1                2668   22.3583   NaN        C
#
#              WikiId                              Name_wiki  Age_wiki  \
# PassengerId
# 1300         1154.0                   Riordan, Miss Hannah      18.0
# 1301         1119.0               Peacock, Miss Treasteall       4.0
# 1302         1064.0                  Naughton, Miss Hannah      21.0
# 1303          206.0  Minahan, Mrs. Lillian E. (née Thorpe)      37.0
# 1304          869.0          Henriksson, Miss Jenny Lovisa      28.0
# 1305         1227.0                     Spector, Mr. Woolf      23.0
# 1306          229.0   and maid, Doña Fermina Oliva y Ocana      39.0
# 1307         1169.0            Sæther, Mr. Simon Sivertsen      43.0
# 1308         1289.0            Ware, Mr. Frederick William      34.0
# 1309          702.0        Butrus-Youssef, Master Makhkhul       4.0
#
#                                     Hometown      Boarded  \
# PassengerId
# 1300               Glenlougha, Cork, Ireland   Queenstown
# 1301         Southampton, Hampshire, England  Southampton
# 1302                    Donoughmore, Ireland   Queenstown
# 1303              Fond du Lac, Wisconsin, US  Southampton
# 1304                       Stockholm, Sweden  Southampton
# 1305                         London, England  Southampton
# 1306                           Madrid, Spain    Cherbourg
# 1307            Skaun, Sør-Trøndelag, Norway  Southampton
# 1308              Greenwich, London, England  Southampton
# 1309                       Sar'al[81], Syria    Cherbourg
#
#                              Destination Lifeboat  Body  Class
# PassengerId
# 1300                       New York City       13   NaN    3.0
# 1301           Elizabeth, New Jersey, US      NaN   NaN    3.0
# 1302                       New York City      NaN   NaN    3.0
# 1303          Fond du Lac, Wisconsin, US       14   NaN    1.0
# 1304         Iron Mountain, Michigan, US      NaN   3MB    3.0
# 1305                       New York City      NaN   NaN    3.0
# 1306              New York, New York, US        8   NaN    1.0
# 1307                                  US      NaN  32MB    3.0
# 1308                       New York City      NaN   NaN    3.0
# 1309               Detroit, Michigan, US        D   NaN    3.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 20 columns):
# Survived       891 non-null float64
# Pclass         1309 non-null int64
# Name           1309 non-null object
# Sex            1309 non-null object
# Age            1046 non-null float64
# SibSp          1309 non-null int64
# Parch          1309 non-null int64
# Ticket         1309 non-null object
# Fare           1308 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# WikiId         1304 non-null float64
# Name_wiki      1304 non-null object
# Age_wiki       1302 non-null float64
# Hometown       1304 non-null object
# Boarded        1304 non-null object
# Destination    1304 non-null object
# Lifeboat       502 non-null object
# Body           130 non-null object
# Class          1304 non-null float64
# dtypes: float64(6), int64(3), object(11)
# memory usage: 214.8+ KB

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki', 'Age_wiki',
#        'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body', 'Class'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# WikiId            5
# Name_wiki         5
# Age_wiki          7
# Hometown          5
# Boarded           5
# Destination       5
# Lifeboat        807
# Body           1179
# Class             5
# dtype: int64

# %%
age = data['Age']
age_wiki = data['Age_wiki']

# %%
age.fillna(age_wiki, inplace = True)

# %%
age.isnull().sum()
# Out:
# 4

# %%
age_mean = age.mean()
age.fillna(age_mean, inplace = True)
age.isnull().sum()
# Out:
# 0

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki', 'Age_wiki',
#        'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body', 'Class'],
#       dtype='object')

# %%
data.drop('Age_wiki', inplace=True,axis=1)

# %%
data.drop('Name_wiki', inplace=True,axis=1)

# %%
data.drop('WikiId', inplace=True,axis=1)

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'Hometown', 'Boarded', 'Destination',
#        'Lifeboat', 'Body', 'Class'],
#       dtype='object')

# %%
data.info
# Out:
# <bound method DataFrame.info of              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# ...               ...     ...
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 1305                                        Spector, Mr. Woolf    male  23.0
# 1306                              Oliva y Ocana, Dona. Fermina  female  39.0
# 1307                              Saether, Mr. Simon Sivertsen    male  38.5
# 1308                                       Ware, Mr. Frederick    male  34.0
# 1309                                  Peter, Master. Michael J    male   4.0
#
#              SibSp  Parch              Ticket      Fare Cabin Embarked  \
# PassengerId
# 1                1      0           A/5 21171    7.2500   NaN        S
# 2                1      0            PC 17599   71.2833   C85        C
# 3                0      0    STON/O2. 3101282    7.9250   NaN        S
# 4                1      0              113803   53.1000  C123        S
# 5                0      0              373450    8.0500   NaN        S
# ...            ...    ...                 ...       ...   ...      ...
# 1305             0      0           A.5. 3236    8.0500   NaN        S
# 1306             0      0            PC 17758  108.9000  C105        C
# 1307             0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308             0      0              359309    8.0500   NaN        S
# 1309             1      1                2668   22.3583   NaN        C
#
#                                        Hometown      Boarded  \
# PassengerId
# 1                    Bridgerule, Devon, England  Southampton
# 2                        New York, New York, US    Cherbourg
# 3                            Jyväskylä, Finland  Southampton
# 4                   Scituate, Massachusetts, US  Southampton
# 5            Birmingham, West Midlands, England  Southampton
# ...                                         ...          ...
# 1305                            London, England  Southampton
# 1306                              Madrid, Spain    Cherbourg
# 1307               Skaun, Sør-Trøndelag, Norway  Southampton
# 1308                 Greenwich, London, England  Southampton
# 1309                          Sar'al[81], Syria    Cherbourg
#
#                                          Destination Lifeboat  Body  Class
# PassengerId
# 1            Qu'Appelle Valley, Saskatchewan, Canada      NaN   NaN    3.0
# 2                             New York, New York, US        4   NaN    1.0
# 3                                      New York City      14?   NaN    3.0
# 4                        Scituate, Massachusetts, US        D   NaN    1.0
# 5                                      New York City      NaN   NaN    3.0
# ...                                              ...      ...   ...    ...
# 1305                                   New York City      NaN   NaN    3.0
# 1306                          New York, New York, US        8   NaN    1.0
# 1307                                              US      NaN  32MB    3.0
# 1308                                   New York City      NaN   NaN    3.0
# 1309                           Detroit, Michigan, US        D   NaN    3.0
#
# [1309 rows x 17 columns]>

# %%
data.isnull().sum()
# Out:
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# Hometown          5
# Boarded           5
# Destination       5
# Lifeboat        807
# Body           1179
# Class             5
# dtype: int64

# %%
fare = data['Fare']
fare_mean = fare.mean()
fare.fillna(fare_mean, inplace = True)

# %%
data.isnull().sum()
# Out:
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          2
# Hometown          5
# Boarded           5
# Destination       5
# Lifeboat        807
# Body           1179
# Class             5
# dtype: int64

# %%
data.tail(100)
# Out:
#              Survived  Pclass                          Name     Sex   Age  \
# PassengerId
# 1210              NaN       3     Jonsson, Mr. Nils Hilding    male  27.0
# 1211              NaN       2  Jefferys, Mr. Ernest Wilfred    male  22.0
# 1212              NaN       3   Andersson, Mr. Johan Samuel    male  26.0
# 1213              NaN       3         Krekorian, Mr. Neshan    male  25.0
# 1214              NaN       2            Nesson, Mr. Israel    male  26.0
# ...               ...     ...                           ...     ...   ...
# 1305              NaN       3            Spector, Mr. Woolf    male  23.0
# 1306              NaN       1  Oliva y Ocana, Dona. Fermina  female  39.0
# 1307              NaN       3  Saether, Mr. Simon Sivertsen    male  38.5
# 1308              NaN       3           Ware, Mr. Frederick    male  34.0
# 1309              NaN       3      Peter, Master. Michael J    male   4.0
#
#              SibSp  Parch              Ticket      Fare  Cabin Embarked  \
# PassengerId
# 1210             0      0              350408    7.8542    NaN        S
# 1211             2      0          C.A. 31029   31.5000    NaN        S
# 1212             0      0              347075    7.7750    NaN        S
# 1213             0      0                2654    7.2292  F E57        C
# 1214             0      0              244368   13.0000     F2        S
# ...            ...    ...                 ...       ...    ...      ...
# 1305             0      0           A.5. 3236    8.0500    NaN        S
# 1306             0      0            PC 17758  108.9000   C105        C
# 1307             0      0  SOTON/O.Q. 3101262    7.2500    NaN        S
# 1308             0      0              359309    8.0500    NaN        S
# 1309             1      1                2668   22.3583    NaN        C
#
#                                  Hometown      Boarded  \
# PassengerId
# 1210                Tågarp, Skåne, Sweden  Southampton
# 1211            Guernsey, Channel Islands  Southampton
# 1212            Hartford, Connecticut, US  Southampton
# 1213                         Kiğı, Turkey    Cherbourg
# 1214                      London, England  Southampton
# ...                                   ...          ...
# 1305                      London, England  Southampton
# 1306                        Madrid, Spain    Cherbourg
# 1307         Skaun, Sør-Trøndelag, Norway  Southampton
# 1308           Greenwich, London, England  Southampton
# 1309                    Sar'al[81], Syria    Cherbourg
#
#                             Destination Lifeboat  Body  Class
# PassengerId
# 1210                      New York City      NaN   NaN    3.0
# 1211          Elizabeth, New Jersey, US      NaN   NaN    2.0
# 1212          Hartford, Connecticut, US      NaN   NaN    3.0
# 1213         Brantford, Ontario, Canada       10   NaN    3.0
# 1214          Boston, Massachusetts, US      NaN   NaN    2.0
# ...                                 ...      ...   ...    ...
# 1305                      New York City      NaN   NaN    3.0
# 1306             New York, New York, US        8   NaN    1.0
# 1307                                 US      NaN  32MB    3.0
# 1308                      New York City      NaN   NaN    3.0
# 1309              Detroit, Michigan, US        D   NaN    3.0
#
# [100 rows x 17 columns]

# %%
data['Embarked'].mode()[0]
# Out:
# 'S'

# %%
data['Embarked'] = data['Embarked'].fillna(data['Embarked'].mode()[0])

# %%
data.isnull().sum()
# Out:
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# Hometown          5
# Boarded           5
# Destination       5
# Lifeboat        807
# Body           1179
# Class             5
# dtype: int64

# %%
data['Hometown'].mode()[0]
data['Hometown'] = data['Hometown'].fillna(data['Hometown'].mode()[0])

# %%
data['Boarded'].mode()[0]
data['Boarded'] = data['Boarded'].fillna(data['Boarded'].mode()[0])
data['Destination'].mode()[0]
data['Destination'] = data['Destination'].fillna(data['Destination'].mode()[0])
data['Class'].mode()[0]
data['Class'] = data['Class'].fillna(data['Class'].mode()[0])

# %%
data.isnull().sum()
# Out:
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          0
# Hometown          0
# Boarded           0
# Destination       0
# Lifeboat        807
# Body           1179
# Class             0
# dtype: int64

# %%
data.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare     Class
# Survived  1.000000 -0.338481 -0.057458 -0.035322  0.081629  0.257307 -0.340696
# Pclass   -0.338481  1.000000 -0.417641  0.060832  0.018322 -0.558477  0.992947
# Age      -0.057458 -0.417641  1.000000 -0.246501 -0.123408  0.182942 -0.416175
# SibSp    -0.035322  0.060832 -0.246501  1.000000  0.373587  0.160224  0.061083
# Parch     0.081629  0.018322 -0.123408  0.373587  1.000000  0.221522  0.020773
# Fare      0.257307 -0.558477  0.182942  0.160224  0.221522  1.000000 -0.546468
# Class    -0.340696  0.992947 -0.416175  0.061083  0.020773 -0.546468  1.000000

# %%
plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)})

# %%
data['Survived'].plot(kind='hist', title='map');
